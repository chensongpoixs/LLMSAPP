# %%
# !pip install tiktoken
# Out:
# Looking in indexes: https://pypi.doubanio.com/simple
# Collecting tiktoken
#   Downloading https://mirrors.cloud.tencent.com/pypi/packages/5f/d2/82e795a6a9bafa034bf26a58e68fe9a89eeaaa610d51dbeb22106ba04f0a/tiktoken-0.12.0-cp310-cp310-win_amd64.whl (879 kB)
#      ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#      ----------- ---------------------------- 262.1/879.4 kB ? eta -:--:--
#      ---------------------------------------- 879.4/879.4 kB 3.0 MB/s  0:00:00
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading https://mirrors.cloud.tencent.com/pypi/packages/34/9d/e9e8493a85f3b1ddc4a5014465f5c2b78c3ea1cbf238dcfde78956378041/regex-2025.11.3-cp310-cp310-win_amd64.whl (277 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\chensong\.conda\envs\llm31018\lib\site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chensong\.conda\envs\llm31018\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chensong\.conda\envs\llm31018\lib\site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chensong\.conda\envs\llm31018\lib\site-packages (from requests>=2.26.0->tiktoken) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chensong\.conda\envs\llm31018\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.11.12)
# Installing collected packages: regex, tiktoken
#
#    -------------------- ------------------- 1/2 [tiktoken]
#    ---------------------------------------- 2/2 [tiktoken]
#
# Successfully installed regex-2025.11.3 tiktoken-0.12.0

# %%
import tiktoken;

# 打印 tiktoken 版本
print('tiktoke version:', tiktoken.__version__);

# 打印全部编码器
print(tiktoken.list_encoding_names());
# Out:
# tiktoke version: 0.12.0
# ['gpt2', 'r50k_base', 'p50k_base', 'p50k_edit', 'cl100k_base', 'o200k_base', 'o200k_harmony']

# %%
# 选择编码器
encoding = tiktoken.get_encoding("cl100k_base");

#print(encoding.encode("人工智能是未来的趋势。"));

# 编码与解码示例
text = "人工智能是未来的趋势。"
encoded = encoding.encode(text);
print("Encoded:", encoded);
print("趋势Encoded:" encoding.encode("趋势"));
decoded = encoding.decode(encoded);
print("Decoded:", decoded);
print("Original and Decoded are the same:", text == decoded);
# Out:
# Encoded: [17792, 49792, 45114, 118, 27327, 21043, 39442, 37507, 9554, 50266, 233, 8239, 123, 1811]
# Decoded: 人工智能是未来的趋势。
# Original and Decoded are the same: True
