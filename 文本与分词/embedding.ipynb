# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
import torch;
import tiktoken;

print('torch version:', torch.__version__);
print('cuda available:', torch.cuda.is_available());
print('cuda device count:', torch.cuda.device_count());
print('cuda current device:', torch.cuda.current_device());
print('cuda device name:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'N/A');
print('cuda device capabilites:', torch.cuda.get_device_capability(0) if torch.cuda.is_available() else 'N/A');
print('torch home:', torch.hub.get_dir());
print('torch default dtype:', torch.get_default_dtype());   
print('torch default device:', torch.device('cuda' if torch.cuda.is_available() else 'cpu'));
print('torch memory allocated (MB):', torch.cuda.memory_allocated(0) / 1024 / 1024 if torch.cuda.is_available() else 'N/A');
print('torch memory reserved (MB):', torch.cuda.memory_reserved(0) / 1024 / 1024 if torch.cuda.is_available() else 'N/A');
print('torch memory max reserved (MB):', torch.cuda.max_memory_reserved(0) / 1024 / 1024 if torch.cuda.is_available() else 'N/A');
print('torch cudnn version:', torch.backends.cudnn.version());
print('torch cudnn enabled:', torch.backends.cudnn.enabled);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch;
#       2 print('torch version:', torch.__version__);
#       3 print('cuda available:', torch.cuda.is_available());
#
# ModuleNotFoundError: No module named 'torch'

# %%
# tiktoken 相关信息
print('tiktoke version:', tiktoken.__version__);
print(tiktoken.list_encoding_names());
enc = tiktoken.get_encoding('gpt2');
# vocatulary size
print('gpt2 vocatulary size:', enc.n_vocab);

# %% [markdown]
# # 设置Embedding 行数就是词的个数
# vocab_size =  enc.n_vocab
# output_dim = 768
# torch.manual_seed(123)
# emb_tab_layer = torch.nn.Embedding(vocab_size, output_dim)
# print(emb_tab_layer.weight.shape)
# #print(emb_tab_layer.weight)

# %%
tokenIDs = torch.tensor([3])
print(emb_tab_layer(tokenIDs))
